# %% [markdown]
# # Examen final de Desarrollo de Aplicaciones para la Visualización de Datos
#
# Nombre: Marian
#
# Apellidos: Moreno Nieto
#
# Tiempo: 2 horas y 30 minutos
#
# ## Contexto del ejercicio
#
# Una gran compañía aseguradora de salud desea entender con mayor profundidad los patrones de coste médico, el uso de servicios sanitarios y los factores que determinan el riesgo clínico de sus asegurados.
#
# La empresa cree que ciertos hábitos de vida, condiciones crónicas y características del seguro tienen un fuerte impacto sobre:
#
# - Los costes médicos anuales (annual_medical_cost)
# - El total pagado en reclamaciones médicas (total_claims_paid)
# - La utilización de servicios médicos, incluyendo consultas, hospitalizaciones y procedimientos
# - De que depende de que un asegurado sea clasificado como de alto riesgo (is_high_risk)
#
# La aseguradora sospecha que estos resultados están influenciados por variables relacionadas con:
#
# - Hábitos de vida (bmi, smoker, alcohol, ejercicio…)
# - Enfermedades crónicas (diabetes, hipertensión, cardiopatías…)
# - Características del seguro (tipo de plan, deducible, copago, calidad del proveedor)
#
# Tu rol será actuar como Analista de Datos, llevando a cabo un análisis que permita identificar patrones significativos y generar recomendaciones accionables para la aseguradora.
#
# ## Tareas obligatorias a realizar:
#
# 1. Análisis exploratorio con clusterización (mínimo 6 gráficos)
# 2. Entrena un modelo y explicable, a elegir entre:
#     - Clasificación para predecir __is_high_risk__
#     - Regresión para predecir __annual_medical_cost__
# 3. Dashboard con mínimo 4 visualizaciones (3 gráficas + 1 coeficientes)
# 4. Informe ejecutivo de dos páginas con:
#     - Los hallazgos más relevantes del análisis exploratorio
#     - Insights principales del modelo predictivo
#     - El dashboard con los 4 gráficos más representativos
#     - Recomendaciones accionables basadas en los datos
#
# ## Entregable y puntuación
#
# Se entregará un informe con la siguiente estructura:
#
# 1. Resumen ejecutivo (3 puntos) + dashboard (2 puntos)
# 2. Gráficas del análisis exploratorio y breve explicación de cada una (3 puntos)
# 3. Modelo predictivo explicado (2 puntos)
#
# ## Entrega del exámen
#
# Subir al siguiente enlace tu informe en **formato PDF**.
#
# https://forms.office.com/e/zPHcGS22x9
#
# En el repo existe un .docx con el formato para entregar el informe.
#
# ## Juego de datos
#
# Para realizar este análisis se provee el fichero __medical_insurance.csv__ con las siguientes variables:
#
# **Rows:** 100,000
# **Columns:** 54+
#
# | **Categoría**                           | **Variable**                | **Tipo (esperado)** | **Descripción / Significado**                         |
# | --------------------------------------- | --------------------------- | ------------------- | ----------------------------------------------------- |
# | **Demographics & Socioeconomic**        |                             |                     |                                                       |
# |                                         | person_id                   | string/int          | Identificador único de la persona.                    |
# |                                         | age                         | int                 | Edad del individuo.                                   |
# |                                         | sex                         | category            | Sexo (male/female/other).                             |
# |                                         | region                      | category            | Región geográfica donde reside.                       |
# |                                         | urban_rural                 | category            | Tipo de zona (urbana vs rural).                       |
# |                                         | income                      | float               | Nivel de ingresos anuales.                            |
# |                                         | education                   | category            | Nivel educativo alcanzado.                            |
# |                                         | marital_status              | category            | Estado civil (single, married, divorced…).            |
# |                                         | employment_status           | category            | Situación laboral (employed, unemployed, retired…).   |
# |                                         | household_size              | int                 | Número total de personas en el hogar.                 |
# |                                         | dependents                  | int                 | Número de dependientes económicos.                    |
# | **Lifestyle & Habits**                  |                             |                     |                                                       |
# |                                         | bmi                         | float               | Índice de masa corporal.                              |
# |                                         | smoker                      | category/bool       | Si la persona es fumadora.                            |
# |                                         | alcohol_freq                | category            | Frecuencia de consumo de alcohol.                     |
# |                                         | exercise_frequency          | category/int        | Frecuencia de ejercicio semanal.                      |
# |                                         | sleep_hours                 | float               | Promedio de horas de sueño diario.                    |
# |                                         | stress_level                | int                 | Nivel de estrés percibido (escala ordinal).           |
# | **Health & Clinical**                   |                             |                     |                                                       |
# |                                         | hypertension                | bool                | Diagnóstico de hipertensión.                          |
# |                                         | diabetes                    | bool                | Diagnóstico de diabetes.                              |
# |                                         | copd                        | bool                | Enfermedad pulmonar obstructiva crónica.              |
# |                                         | cardiovascular              | bool                | Enfermedad cardiovascular.                            |
# |                                         | cancer_history              | bool                | Antecedente personal de cáncer.                       |
# |                                         | kidney_disease              | bool                | Enfermedad renal crónica.                             |
# |                                         | liver_disease               | bool                | Enfermedad hepática crónica.                          |
# |                                         | arthritis                   | bool                | Diagnóstico de artritis.                              |
# |                                         | mental_health               | bool/category       | Algún trastorno de salud mental reportado.            |
# |                                         | chronic_count               | int                 | Número total de enfermedades crónicas diagnosticadas. |
# |                                         | systolic_bp                 | int                 | Presión arterial sistólica.                           |
# |                                         | diastolic_bp                | int                 | Presión arterial diastólica.                          |
# |                                         | ldl                         | float               | Colesterol LDL.                                       |
# |                                         | hba1c                       | float               | Hemoglobina glicosilada, indicador de diabetes.       |
# |                                         | risk_score                  | float               | Puntuación compuesta de riesgo clínico.               |
# |                                         | is_high_risk                | bool                | Indicador de alto riesgo clínico.                     |
# | **Healthcare Utilization & Procedures** |                             |                     |                                                       |
# |                                         | visits_last_year            | int                 | Visitas médicas en el último año.                     |
# |                                         | hospitalizations_last_3yrs  | int                 | Número de hospitalizaciones en 3 años.                |
# |                                         | days_hospitalized_last_3yrs | int                 | Días totales hospitalizado en 3 años.                 |
# |                                         | medication_count            | int                 | Cantidad de medicamentos activos.                     |
# |                                         | proc_imaging                | int                 | Cantidad de estudios de imagen realizados.            |
# |                                         | proc_surgery                | int                 | Número de procedimientos quirúrgicos.                 |
# |                                         | proc_psycho                 | int                 | Número de consultas/procedimientos de psicología.     |
# |                                         | proc_consult_count          | int                 | Número total de consultas médicas.                    |
# |                                         | proc_lab                    | int                 | Número de exámenes de laboratorio.                    |
# |                                         | had_major                   | bool                | Si tuvo un procedimiento mayor (cirugía importante).  |
# | **Insurance & Policy**                  |                             |                     |                                                       |
# |                                         | plan_type                   | category            | Tipo de plan (HMO, PPO, etc.).                        |
# |                                         | network_tier                | category            | Nivel de red (gold/silver/bronze).                    |
# |                                         | deductible                  | float               | Deducible anual del seguro.                           |
# |                                         | copay                       | float               | Copago por servicio.                                  |
# |                                         | policy_term_years           | int                 | Duración del contrato del seguro.                     |
# |                                         | policy_changes_last_2yrs    | int                 | Cambios realizados a la póliza en 2 años.             |
# |                                         | provider_quality            | float               | Índice de calidad del proveedor.                      |
# | **Medical Costs & Claims**              |                             |                     |                                                       |
# |                                         | annual_medical_cost         | float               | Coste médico anual real del paciente.                 |
# |                                         | annual_premium              | float               | Prima anual pagada por el paciente.                   |
# |                                         | monthly_premium             | float               | Prima mensual pagada.                                 |
# |                                         | claims_count                | int                 | Número de reclamaciones realizadas.                   |
# |                                         | avg_claim_amount            | float               | Valor promedio por reclamación.                       |
# |                                         | total_claims_paid           | float               | Total pagado por la compañía aseguradora.             |
#
# Ejemplos de preguntas que se pueden realizar a los datos:
# 1. ¿Cómo varía el coste médico anual según edad, sexo y región?
# 2. ¿Qué relación existe entre hábitos de vida (bmi, smoker, alcohol_freq…) y el coste médico anual?
# 3. ¿Cuánto más cuesta un paciente de alto riesgo respecto a uno de bajo riesgo?
# 4. ¿Qué enfermedades crónicas generan mayores costes promedio?
# 5. ¿Existe relación entre hospitalizaciones y coste total en los últimos 3 años?
# 6. ¿Qué parámetros clínicos tienen mayor correlación con el coste médico?
# 7. ¿Qué tipos de seguro están asociados con mayor gasto?
# 8. ¿Cómo se relacionan los procedimientos médicos con el total pagado en reclamaciones?
# 9. ¿Qué variables explican mejor los costes según un modelo predictivo?
# 10. ¿Qué grupos de pacientes comparten patrones similares de riesgo y coste (clustering)?
#
# Nota:
# - Se valorará la creatividad en las hipótesis, soluciones y limpieza del código y visualizaciones.

# %% [markdown]
# ### notas

# %%
Identificar el gasto meido de la aseguradora, el financiero lo unico que uqiere es reducir gasto medio (si es 300 por ususario pues a 200 par opitmizar la cartera poblacional

# %% [markdown]
# Carga tus librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %% [markdown]
# Escribe tu código

# %% [markdown]
# ## 1. Descripción y limpieza de los datos

# %%
df = pd.read_csv("medical_insurance.csv")  
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 54 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   person_id                    100000 non-null  int64
#  1   age                          100000 non-null  int64
#  2   sex                          100000 non-null  object
#  3   region                       100000 non-null  object
#  4   urban_rural                  100000 non-null  object
#  5   income                       100000 non-null  float64
#  6   education                    100000 non-null  object
#  7   marital_status               100000 non-null  object
#  8   employment_status            100000 non-null  object
#  9   household_size               100000 non-null  int64
#  10  dependents                   100000 non-null  int64
#  11  bmi                          100000 non-null  float64
# ...

# %%
df.describe()
# Out:
#            person_id            age        income  household_size  \
# count  100000.000000  100000.000000  1.000000e+05   100000.000000
# mean    50000.500000      47.521500  4.987390e+04        2.430900
# std     28867.657797      15.988752  4.680021e+04        1.075126
# min         1.000000       0.000000  1.100000e+03        1.000000
# 25%     25000.750000      37.000000  2.110000e+04        2.000000
# 50%     50000.500000      48.000000  3.620000e+04        2.000000
# 75%     75000.250000      58.000000  6.220000e+04        3.000000
# max    100000.000000     100.000000  1.061800e+06        9.000000
#
#           dependents            bmi  visits_last_year  \
# count  100000.000000  100000.000000      100000.00000
# mean        0.898380      26.990512           1.92765
# std         0.950654       4.994883           1.73773
# min         0.000000      12.000000           0.00000
# 25%         0.000000      23.600000           1.00000
# ...

# %%
df.isna().sum() # aqui no hay
# Out:
# person_id                          0
# age                                0
# sex                                0
# region                             0
# urban_rural                        0
# income                             0
# education                          0
# marital_status                     0
# employment_status                  0
# household_size                     0
# dependents                         0
# bmi                                0
# smoker                             0
# alcohol_freq                   30083
# visits_last_year                   0
# hospitalizations_last_3yrs         0
# days_hospitalized_last_3yrs        0
# medication_count                   0
# systolic_bp                        0
# diastolic_bp                       0
# ldl                                0
# hba1c                              0
# plan_type                          0
# network_tier                       0
# deductible                         0
# ...

# %%
df.describe(exclude="number")     # solo categóricass() # solo categóricas
# Out:
#            sex  region urban_rural  education marital_status  \
# count   100000  100000      100000     100000         100000
# unique       3       5           3          6              4
# top     Female   South       Urban  Bachelors        Married
# freq     49193   28029       60019      27996          53252
#
#        employment_status  smoker alcohol_freq plan_type network_tier
# count             100000  100000       100000    100000       100000
# unique                 4       3            4         4            4
# top             Employed   Never   Occasional       PPO       Silver
# freq               55269   69709        45078     35167        40177

# %%
df["sex"].value_counts()
# Out:
# sex
# Female    49193
# Male      48794
# Other      2013
# Name: count, dtype: int64

# %%
df["region"].value_counts()
# Out:
# region
# South      28029
# North      22027
# East       19984
# West       17879
# Central    12081
# Name: count, dtype: int64

# %% [markdown]
# ### Limpieza de datos
#
# Tenemos que rellenar los datos nulos de alcohol_freq; daremos por hecho que los nan será que no hay uso de alcohol y por tanto rellenamos con None

# %%
df["alcohol_freq"].value_counts()
# Out:
# alcohol_freq
# Occasional    45078
# Weekly        19833
# Daily          5006
# Name: count, dtype: int64

# %%
df["alcohol_freq"]=df["alcohol_freq"].fillna("None")

# %%
df["alcohol_freq"].value_counts()
# Out:
# alcohol_freq
# Occasional    45078
# None          30083
# Weekly        19833
# Daily          5006
# Name: count, dtype: int64

# %% [markdown]
# Comprobamos que hemos rellenado bien; ahora podemos proceder a la visualización de nuestro datos

# %%
df["profit"] = df["annual_medical_cost"] - df["annual_premium"]

# %%
df.head()
# Out:
#    person_id  age     sex   region urban_rural   income     education  \
# 0      75722   52  Female    North    Suburban  22700.0     Doctorate
# 1      80185   79  Female    North       Urban  12800.0         No HS
# 2      19865   68    Male    North       Rural  40700.0            HS
# 3      76700   15    Male    North    Suburban  15600.0  Some College
# 4      92992   53    Male  Central    Suburban  89600.0     Doctorate
#
#   marital_status employment_status  household_size  ...  arthritis  \
# 0        Married           Retired               3  ...          1
# 1        Married          Employed               3  ...          1
# 2        Married           Retired               5  ...          0
# 3        Married     Self-employed               5  ...          0
# 4        Married     Self-employed               2  ...          1
#
#    mental_health proc_imaging_count proc_surgery_count  proc_physio_count  \
# ...

# %% [markdown]
# #### Creracion de variable profit
# Hemos creado la variable profit (saber cuanto esta ganando la aseguradora con ese paciente, como la resta entre el gasto anual de ese paciente (lo que paga la aseguradora) y la prima anual (lo que recibe)

# %% [markdown]
# ### Visualización de datos

# %% [markdown]
# 1. Vamos a ver el gasto medio que hay por tipo de seguro; además de comparar con la prima que paga el paciente y con el coste para la aseguradora (+ el prfit)

# %%
# ============================================================
# 3. AGRUPAR por seguro
# ============================================================

# Seleccionar SOLO las columnas numéricas (para evitar errores)
df_numeric = df.select_dtypes(include=["float", "int"])

# Agrupar por seguros y calcular medias SOLO de las numéricas
df_agg_seguro = df.groupby("plan_type")[df_numeric.columns].mean().reset_index()

# Mostrar primeras filas agregadas
df_agg_seguro.head()
# Out:
#   plan_type     person_id        age        income  household_size  \
# 0       EPO  49835.554924  47.675021  50164.499702        2.442431
# 1       HMO  49847.510785  47.446620  49718.157993        2.425654
# 2       POS  49985.576890  47.635266  49972.820068        2.427313
# 3       PPO  50228.840817  47.480934  49860.576677        2.432650
#
#    dependents        bmi  visits_last_year  hospitalizations_last_3yrs  \
# 0    0.908868  27.022379          1.936578                    0.094041
# 1    0.893903  26.975791          1.929240                    0.092907
# 2    0.893989  26.961919          1.916139                    0.091667
# 3    0.900162  27.003532          1.927148                    0.095032
#
#    days_hospitalized_last_3yrs  ...  arthritis  mental_health  \
# 0                     0.379538  ...   0.111633       0.130150
# 1                     0.365953  ...   0.108026       0.129683
# 2                     0.364200  ...   0.104610       0.131697
# ...

# %%
plt.figure(figsize=(12,5))

df.groupby("plan_type")[["annual_medical_cost", "annual_premium", "profit","total_claims_paid"]].mean().sort_values("annual_medical_cost").plot(
    kind="bar"
)

plt.title("Costes por tipo seguro")
plt.xlabel("Tipo seguro")
plt.ylabel("Precio medio")
plt.xticks(rotation=45)
plt.show()

# %%
df_table = df.groupby("plan_type")[["annual_medical_cost", "annual_premium", "profit", "total_claims_paid"]].agg(["mean", "median"])
print(df_table)
# Out:
#           annual_medical_cost          annual_premium               profit  \
#                          mean   median           mean  median         mean
# plan_type
# EPO               2994.298085  2063.94     581.264274  462.32  2413.033811
# HMO               3014.030615  2083.32     581.774691  463.56  2432.255924
# POS               3005.430057  2100.15     582.560302  466.96  2422.869754
# PPO               3013.161008  2082.83     583.210052  463.02  2429.950956
#
#                    total_claims_paid
#             median              mean  median
# plan_type
# EPO        1591.30       1366.295168  634.86
# HMO        1612.30       1387.851663  651.03
# POS        1628.02       1373.855489  663.56
# PPO        1615.30       1374.727449  630.19

# %% [markdown]
# #### Observaciones (tabla + visualizacion
# Podemos ver como el tipo de seguro no afecta ya que la media de costes del paciente; , la media pagada a modo de prima a la aseguradora y el total de claims pagadas es mnuy parecida en todos los tipos de seguro
# -Además el beneficio (coste anual-prima anual) podemos

# %% [markdown]
# ### Visualizacion 2:

# %%
# ============================================================
#   OBTENER LAS 10 VARIABLES MÁS CORRELACIONADAS CON el coste anual
# ============================================================

# 1. Seleccionar solo columnas numéricas (para evitar errores)
numeric_df = df.select_dtypes(include=["float", "int"])

# 2. Calcular la correlación de TODAS las numéricas con m2_price
corr_with_price = numeric_df.corr()["annual_medical_cost"].sort_values(ascending=False)

# 3. Seleccionar las 5 correlaciones más fuertes (excluyendo m2_price)
top20 = corr_with_price.iloc[1:21]   # desde el segundo valor (evitamos m2_price=1)

print("Top 20 variables más correlacionadas con coste anual:")
print(top20)
# Crear un DataFrame solo con las 10 variables + coste anual
cols_to_plot = ["annual_medical_cost"] + top15.index.tolist()
df_top = numeric_df[cols_to_plot]

plt.figure(figsize=(10,8))
sns.heatmap(df_top.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap de las 10 variables más correlacionadas con el coste anual medico")
plt.show()
# Out:
# Top 20 variables más correlacionadas con coste anual:
# profit                         0.999279
# monthly_premium                0.965416
# annual_premium                 0.965415
# total_claims_paid              0.739402
# avg_claim_amount               0.632996
# risk_score                     0.305971
# chronic_count                  0.296720
# is_high_risk                   0.251923
# days_hospitalized_last_3yrs    0.230246
# hospitalizations_last_3yrs     0.208640
# visits_last_year               0.195631
# claims_count                   0.179082
# hypertension                   0.154309
# had_major_procedure            0.148292
# systolic_bp                    0.145070
# age                            0.131166
# mental_health                  0.126232
# diastolic_bp                   0.117647
# arthritis                      0.115375
# medication_count               0.113456
# Name: annual_medical_cost, dtype: float64

# %% [markdown]
# ### Observación,
# Quitando la variables obvias con correlacion (todas las relacionadas con costes y pagos encontramos que las variables que mas van a afectar al coste (es decir correlacionadas positivamente con el coste anual por paciente son:
# Grupo 1 (0,3-0,2) de correlacion: pacientes con mucho riesgo y con muchos dias de visita (mucho tiempo en el hospital)
# - risk
# - chronic countr : num total de enfermedades
# - numero total de hospitalizaciones y dias
# - numero total de visitas
# - numero de claims (vemos como esta afecta bastante menos, que por ejemplo el avg amount del claim)
#
#
# Grupo 2 (0,14-0,2)
# - condiciones como systolic bp e hipertension
# - si ha tenido una major procedure o no
#
# Grupo 3 (0,11-0,14)
# - edad
# - otras condiciones (arthritis)
# - cuantos medicamentos se toma (medication count)
#
# Por lo tanto vemos que hay enfermedades que llevan a un mayor gasto como puede ser arthirits, hipertension, dyastolis y systemic bp frente a otras que no tanto y que tiene mucho mas peso por ejemplo el avg pagado por factura (avg_claim_amount a que hayas tenido muchas claims)

# %% [markdown]
# ### Visualizacion 3
#
# Anteriormente hemos visto que el primer factor no relacionado con el precio directametne que afecta el que mas al coste total es el riesgo; por lo que vamos a ver un poco como evoluciona el riesgo segun diferentes factores

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(
    data=df,
    x="age",
    y="risk_score",
    hue="smoker",      # tercera variable como color
    palette="viridis"              # paleta continua bonita
)

plt.title("Risk vs precio €/m2 coloreado por densidad poblacional")
plt.xlabel("Age")
plt.ylabel("risk_score")
plt.legend(title="Sex")   # nombre bonito para la leyenda
plt.show()

# %% [markdown]
# ### Obervaciones
#
# Aqui se puede ver como claramente los puntos verdes (Current o former tienen mucho mas riesgo) con la misma edad; que aquellos que no fuman (morado oscuro; por loq e sabemos que ser fumador (actual afecta mucho al riesgo); luego ser former algo, yq ue si no eres fumador en general tienes mucho menos riesgo

# %%
plt.figure(figsize=(12,5))
df.groupby("region")["risk_score"].mean().sort_values().plot(
    kind="bar", color="teal"
)

plt.title("Riesgo por region")
plt.xlabel("Barrio")
plt.ylabel("Riesgo")
plt.xticks(rotation=45)
plt.legend(["Media m2_price"])
plt.show()

# %%
sns.lmplot(
    data=df,
    x="risk_score",               # variable independiente
    y="days_hospitalized_last_3yrs",                # variable dependiente
    height=5,
    line_kws={"color": "red"},   # línea de regresión en rojo
    scatter_kws={"alpha": 0.5, "color": "skyblue"}  # puntos semitransparentes
)

plt.title("Regresión: riesgo vs dias en hospital")
plt.xlabel("riesgo")
plt.ylabel("dias hospital")
plt.show()

# %%
# PIE CHART: Proporción por barrio
plt.figure(figsize=(7,7))
df["smoker"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",     # mostrar porcentaje
    colors=sns.color_palette("pastel"),  
    startangle=90          # empezar de arriba
)
plt.title("Proporción de smoker en portfolio")
plt.ylabel("")            # quitar nombre del eje
plt.show()

# %%
# PIE CHART: Proporción por barrio
plt.figure(figsize=(7,7))
df["alcohol_freq"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",     # mostrar porcentaje
    colors=sns.color_palette("pastel"),  
    startangle=90          # empezar de arriba
)
plt.title("Proporción de alcohol en portfolio")
plt.ylabel("")            # quitar nombre del eje
plt.show()

# %% [markdown]
# ## 3. Modelo:

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   person_id                    100000 non-null  int64
#  1   age                          100000 non-null  int64
#  2   income                       100000 non-null  float64
#  3   household_size               100000 non-null  int64
#  4   dependents                   100000 non-null  int64
#  5   bmi                          100000 non-null  float64
#  6   visits_last_year             100000 non-null  int64
#  7   hospitalizations_last_3yrs   100000 non-null  int64
#  8   days_hospitalized_last_3yrs  100000 non-null  int64
#  9   medication_count             100000 non-null  int64
#  10  systolic_bp                  100000 non-null  float64
#  11  diastolic_bp                 100000 non-null  float64
# ...

# %%
y = df["annual_medical_cost"]
X = df_numeric.drop(['annual_medical_cost', "annual_premium", "monthly_premium", "profit"], axis=1)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   person_id                    100000 non-null  int64
#  1   age                          100000 non-null  int64
#  2   income                       100000 non-null  float64
#  3   household_size               100000 non-null  int64
#  4   dependents                   100000 non-null  int64
#  5   bmi                          100000 non-null  float64
#  6   visits_last_year             100000 non-null  int64
#  7   hospitalizations_last_3yrs   100000 non-null  int64
#  8   days_hospitalized_last_3yrs  100000 non-null  int64
#  9   medication_count             100000 non-null  int64
#  10  systolic_bp                  100000 non-null  float64
#  11  diastolic_bp                 100000 non-null  float64
# ...

# %%
# ============================================================
# 5. TRAIN / TEST SPLIT
# ============================================================
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)
# 80% train, 20% test


# ============================================================
# 6. ESCALAR VARIABLES (MUY IMPORTANTE)
# ============================================================
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)
# NOTA: .fit solo en train → .transform en test

# %%
# ============================================================
# 7. ENTRENAR MODELO
# ============================================================
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# ============================================================
# 8. PREDICCIONES TRAIN Y TEST
# ============================================================
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
# ============================================================
# 7. MOSTRAR COEFICIENTES DEL MODELO
# ============================================================
coef_table = pd.DataFrame({
    "Variable": X.columns,
    "Coeficiente": model.coef_
}).sort_values(by="Coeficiente", ascending=False)

print("\n=== COEFICIENTES DE LA REGRESIÓN LINEAL ===")
print(coef_table)
# Out:
# === COEFICIENTES DE LA REGRESIÓN LINEAL ===
#                        Variable  Coeficiente
# 19                   risk_score  2175.616776
# 8   days_hospitalized_last_3yrs   227.159313
# 23                chronic_count   127.182092
# 7    hospitalizations_last_3yrs    86.136548
# 40          had_major_procedure    55.766191
# 29               cancer_history    53.113780
# 25                     diabetes    37.550634
# 24                 hypertension    28.697847
# 17     policy_changes_last_2yrs    28.625073
# 28       cardiovascular_disease    23.620475
# 31                liver_disease    21.787513
# 32                    arthritis    11.616167
# 37           proc_consult_count    11.508140
# 4                    dependents     4.431850
# 5                           bmi     3.859246
# 18             provider_quality     3.563552
# 34           proc_imaging_count     1.282442
# 22            total_claims_paid     1.053953
# 16            policy_term_years     0.740905
# ...

# %%
# ============================================================
# 9. MÉTRICAS DE EVALUACIÓN
# ============================================================



# ---- TRAIN ----
train_MSE = mean_squared_error(y_train, y_train_pred)
train_RMSE = np.sqrt(train_MSE)
train_MAE = mean_absolute_error(y_train, y_train_pred)
train_R2 = model.score(X_train, y_train)

# ---- TEST ----
test_MSE = mean_squared_error(y_test, y_test_pred)
test_RMSE = np.sqrt(test_MSE)
test_MAE = mean_absolute_error(y_test, y_test_pred)
test_R2 = model.score(X_test, y_test)


# ============================================================
# 10. TABLA FINAL DE MÉTRICAS
# ============================================================
metrics_table = pd.DataFrame({
    "Métrica": ["R2", "MSE", "RMSE", "MAE"],
    "Train": [train_R2, train_MSE, train_RMSE, train_MAE],
    "Test": [test_R2, test_MSE, test_RMSE, test_MAE]
})

metrics_table
# Out:
#   Métrica         Train          Test
# 0      R2  6.433654e-01  5.967600e-01
# 1     MSE  3.482899e+06  3.967941e+06
# 2    RMSE  1.866253e+03  1.991969e+03
# 3     MAE  1.132398e+03  1.161999e+03

# %%
# ============================================================
# 8. MOSTRAR INTERCEPTO
# ============================================================
print("\nIntercepto del modelo:", model.intercept_)
# Out:
# Intercepto del modelo: 1559.320184074818

# %% [markdown]
# | Métrica                                   | Qué mide                                                                                            | Cómo interpretarla                                                                                           |
# | ----------------------------------------- | --------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------ |
# | **Intercepto (β₀)**                       | Valor estimado de la variable dependiente cuando todas las X = 0 (o X en media si están escaladas). | Sirve como "punto de partida" del modelo. No indica calidad, solo nivel base de Y.                           |
# | **Coeficientes (βᵢ)**                     | Efecto de cada variable X sobre Y.                                                                  | βᵢ > 0 → X aumenta Y. βᵢ < 0 → X reduce Y. Más grande = más influencia.                                      |
# | **R² (Coeficiente de determinación)**     | Proporción de variabilidad de Y explicada por el modelo.                                            | Va de 0 a 1. Cuanto mayor, mejor. Ej.: 0.75 = el 75% de la variabilidad del precio se explica por el modelo. |
# | **RMSE (Root Mean Squared Error)**        | Error medio en la predicción (en misma unidad que Y).                                               | Menor = mejor. Penaliza más los errores grandes.                                                             |
# | **MAE (Mean Absolute Error)**             | Error absoluto medio de predicción.                                                                 | Más robusto que RMSE ante outliers. Menor = mejor.                                                           |
# | **MSE (Mean Squared Error)**              | Error cuadrático medio.                                                                             | Siempre positivo. Menor = mejor. Muy sensible a grandes errores.                                             |

# %% [markdown]
# ### Probamos modelo mas simple para quitar ruido
#
# Nos sale con incluso menos preicsion

# %%
# ============================================================
# 4. SELECCIONAR VARIABLES PARA EL MODELO
# ============================================================
# Y: variable dependiente → precio de vivienda
y = df["annual_medical_cost"]

# X: todas las variables relacionadas con alquiler turístico
features = [
     "risk_score","chronic_count", "days_hospitalized_last_3yrs", "medication_count", "age", "bmi", "hypertension", "cardiovascular_disease", "systolic_bp", "arthritis", "provider_quality", "diabetes","income"]


X = df[features]
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   risk_score                   100000 non-null  float64
#  1   chronic_count                100000 non-null  int64
#  2   days_hospitalized_last_3yrs  100000 non-null  int64
#  3   medication_count             100000 non-null  int64
#  4   age                          100000 non-null  int64
#  5   bmi                          100000 non-null  float64
#  6   hypertension                 100000 non-null  int64
#  7   cardiovascular_disease       100000 non-null  int64
#  8   systolic_bp                  100000 non-null  float64
#  9   arthritis                    100000 non-null  int64
#  10  provider_quality             100000 non-null  float64
#  11  diabetes                     100000 non-null  int64
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)
# ============================================================
# 7. ENTRENAR MODELO
# ============================================================
model = LinearRegression()
model.fit(X_train, y_train)
# ============================================================
# 7. MOSTRAR COEFICIENTES DEL MODELO
# ============================================================
coef_table = pd.DataFrame({
    "Variable": features,
    "Coeficiente": model.coef_
}).sort_values(by="Coeficiente", ascending=False)

print("\n=== COEFICIENTES DE LA REGRESIÓN LINEAL ===")
print(coef_table)
# Out:
# === COEFICIENTES DE LA REGRESIÓN LINEAL ===
#                        Variable  Coeficiente
# 0                    risk_score  4001.247464
# 2   days_hospitalized_last_3yrs   483.014150
# 1                 chronic_count   330.190004
# 6                  hypertension    73.888740
# 9                     arthritis    45.893488
# 11                     diabetes     8.810319
# 5                           bmi     6.333990
# 7        cardiovascular_disease     3.021596
# 12                       income    -0.000432
# 8                   systolic_bp    -1.731274
# 10             provider_quality    -8.626273
# 3              medication_count   -11.840297
# 4                           age   -21.257314

# %%
# ---- TRAIN ----
train_MSE = mean_squared_error(y_train, y_train_pred)
train_RMSE = np.sqrt(train_MSE)
train_MAE = mean_absolute_error(y_train, y_train_pred)
train_R2 = model.score(X_train, y_train)

# ---- TEST ----
test_MSE = mean_squared_error(y_test, y_test_pred)
test_RMSE = np.sqrt(test_MSE)
test_MAE = mean_absolute_error(y_test, y_test_pred)
test_R2 = model.score(X_test, y_test)


# ============================================================
# 10. TABLA FINAL DE MÉTRICAS
# ============================================================
metrics_table = pd.DataFrame({
    "Métrica": ["R2", "MSE", "RMSE", "MAE"],
    "Train": [train_R2, train_MSE, train_RMSE, train_MAE],
    "Test": [test_R2, test_MSE, test_RMSE, test_MAE]
})

metrics_table
# Out:
#   Métrica         Train          Test
# 0      R2  1.576806e-01  1.661885e-01
# 1     MSE  3.482899e+06  3.967941e+06
# 2    RMSE  1.866253e+03  1.991969e+03
# 3     MAE  1.132398e+03  1.161999e+03

# %% [markdown]
# ## 4. Dashboard

# %%
# =============================================================
#      DEFINICIÓN DE FIGURAS — (ESTA CELDA SÍ SE MODIFICA)
# =============================================================

# ❗ REGLA GENERAL:
# Cada función debe devolver:
#    ➤ fig  (la figura a mostrar)
#    ➤ opciones  (lista de opciones para el dropdown)
#
# El dashboard NO se toca, solo estas funciones.

import plotly.express as px
import pandas as pd


# =============================================================
#  FIGURA 1 — HISTOGRAMA (con filtro de barrio)
# =============================================================

def crear_figura_1(df, filtro):
    """
    Esta función crea un histograma filtrado por 'edad'.

    ✔ Qué puedes cambiar:
        - La columna del filtro  → sustituir 'neighbourhood_group'
        - La variable del histograma → cambiar x="m2_price"
        - Número de bins → cambiar nbins=30
        - Paleta → fig.update_traces(marker_color='...')
        - Tipo de gráfica (por ejemplo bar, kde, hist, line…)

    ❌ Qué NO puedes cambiar:
        - El return fig, opciones
        - La estructura del if filtro: (Dashboard depende de ella)
    """

    # ---------------------------------------------------------
    # OPCIONES DEL DROPDOWN
    # Si quieres otro filtro, CAMBIA ESTA LÍNEA ↓
    # ---------------------------------------------------------
    opciones = [{"label": b, "value": b}
                for b in df["sex"].unique()]

    # ---------------------------------------------------------
    # APLICAR FILTRO
    # Si quieres filtrar por otra columna sustituye 'neighbourhood_group'
    # ---------------------------------------------------------
    if filtro:
        datos = df[df["sex"] == filtro]
    else:
        datos = df

    # ---------------------------------------------------------
    # GRÁFICA (modificable)
    # Cambia:
    #    - x="m2_price"
    #    - nbins
    #    - color, title, opacity…
    # ---------------------------------------------------------
    fig = px.histogram(
        datos,
        x="risk_score",
        nbins=30,
        title=f"Histograma riesgo  (Filtro: {filtro})"
    )

    # Ejemplo de colores opcionales:
    # fig.update_traces(marker_color="purple")

    return fig, opciones



# =============================================================
#  FIGURA 2 — LÍNEA TEMPORAL (filtro por barrio)
# =============================================================

def crear_figura_2(df, filtro):
    """


    ❌ No tocar:
        - return fig, opciones
        - estructura del df.copy()
    """
    opciones = "modelo"
    # Opciones del filtro (mismas reglas que arriba)
    # opciones = [{"label": b, "value": b}
    #             for b in df["neighbourhood_group"].unique()]
    
    fig = px.bar(coef_table, x = "Variable", y = "Coeficiente", title = "Distribución de los coeficientes del modelo")



#     # Convertir fecha (NO borrar esta línea)
#     df = df.copy()
#     df["date"] = pd.to_datetime(df["date"])

#     # Aplicar filtro
#     if filtro:
#         datos = df[df["neighbourhood_group"] == filtro]
#     else:
#         datos = df

#     fig = px.line(
#         datos,
#         x="date",
#         y="m2_price",
#         title=f"Evolución precio €/m2 (Filtro: {filtro})"
#     )

    # Opcional: estilo de línea
    # fig.update_traces(line=dict(color="red", width=2))

    return fig, opciones



# =============================================================
#  FIGURA 3 — SCATTER (relación entre 2 numéricas)
# =============================================================

def crear_figura_3(df, filtro):
    """

        - return fig, opciones
    """

    opciones = [{"label": b, "value": b}
                for b in df["had_major_procedure"].unique()]

    # Aplicar filtro
    if filtro:
        datos = df[df["had_major_procedure"] == filtro]
    else:
        datos = df

    # Scatter básico
    fig = px.scatter(
        datos,
        x="age",
        y="days_hospitalized_last_3yrs",
        color="alcohol_freq",  # <- cambiable
        title=f"Dias en hospital por edad y en en funcion de si ha tenido major procedure o no (Filtro: {filtro})"
    )

    # Opcional: cambiar paleta
    # fig.update_traces(marker=dict(colorscale="Viridis"))

    return fig, opciones



# =============================================================
#  FIGURA 4 — BOXPLOT (comparar categorías)
# =============================================================

def crear_figura_4(df, filtro):
    """
    
    """

    opciones = [{"label": b, "value": b}
                for b in df["is_high_risk"].unique()]

    if filtro:
        datos = df[df["is_high_risk"] == filtro]
    else:
        datos = df

    fig = px.box(
        datos,
        x="smoker",
        y="risk_score",
        title=f"Distribución de riesgo filtrando por high/low risk (Filtro: {filtro})"
    )

    # Si quieres un violin plot:
    # fig = px.violin(datos, x="neighbourhood_group", y="m2_price", box=True)

    return fig, opciones

# %%
# =============================================================
#  DASHBOARD — PLANTILLA FIJA (NO MODIFICAR)
# =============================================================

from dash import Dash, html, dcc, Input, Output
import plotly.express as px
import pandas as pd

# =============================================================
#  IMPORTAR DATASET (solo cambia el archivo si quieres)
# =============================================================
df = pd.read_csv("medical_insurance.csv")
coef_table =  pd.DataFrame({
    "Variable": features,
    "Coeficiente": model.coef_
}).sort_values(by="Coeficiente", ascending=False)

# =============================================================
#  IMPORTAR FIGURAS Y FILTROS DESDE LA CELDA 2
# =============================================================
fig1_default, filtro1_opciones = crear_figura_1(df, None)
fig2_default, filtro2_opciones = crear_figura_2(df, None)
fig3_default, filtro3_opciones = crear_figura_3(df, None)
fig4_default, filtro4_opciones = crear_figura_4(df, None)

# =============================================================
#  CREAR APP (NO MODIFICAR)
# =============================================================
app = Dash(__name__)

# =============================================================
#  LAYOUT — 2x2 figuras con filtros independientes
# =============================================================
app.layout = html.Div([

    html.H1("Dashboard – 4 Figuras Interactivas", style={"textAlign": "center"}),

    # ---------------------------------------------------------
    # FILA 1 — FIGURA 1 + FIGURA 2
    # ---------------------------------------------------------

    html.Div([
        
        # ---------------- FIGURA 1 ----------------
        html.Div([
            html.H3("Figura 1"),
            dcc.Dropdown(
                id="filtro1",
                options=filtro1_opciones,
                value=None,
                placeholder="Selecciona filtro para Figura 1",
                style={"margin-bottom": "10px"}
            ),
            dcc.Graph(id="fig1", figure=fig1_default)
        ], style={"width": "48%", "display": "inline-block"}),

        # ---------------- FIGURA 2 ----------------
        html.Div([
            html.H3("Figura 2"),
            dcc.Dropdown(
                id="filtro2",
                options=filtro2_opciones,
                value=None,
                placeholder="Selecciona filtro para Figura 2",
                style={"margin-bottom": "10px"}
            ),
            dcc.Graph(id="fig2", figure=fig2_default)
        ], style={"width": "48%", "display": "inline-block", "float": "right"}),

    ], style={"margin-bottom": "40px"}),

    # ---------------------------------------------------------
    # FILA 2 — FIGURA 3 + FIGURA 4
    # ---------------------------------------------------------

    html.Div([
        
        # ---------------- FIGURA 3 ----------------
        html.Div([
            html.H3("Figura 3"),
            dcc.Dropdown(
                id="filtro3",
                options=filtro3_opciones,
                value=None,
                placeholder="Selecciona filtro para Figura 3",
                style={"margin-bottom": "10px"}
            ),
            dcc.Graph(id="fig3", figure=fig3_default)
        ], style={"width": "48%", "display": "inline-block"}),

        # ---------------- FIGURA 4 ----------------
        html.Div([
            html.H3("Figura 4"),
            dcc.Dropdown(
                id="filtro4",
                options=filtro4_opciones,
                value=None,
                placeholder="Selecciona filtro para Figura 4",
                style={"margin-bottom": "10px"}
            ),
            dcc.Graph(id="fig4", figure=fig4_default)
        ], style={"width": "48%", "display": "inline-block", "float": "right"}),

    ], style={"margin-bottom": "40px"}),

])

# =============================================================
#  CALLBACKS PARA CADA GRÁFICA (NO MODIFICAR)
# =============================================================

@app.callback(
    Output("fig1", "figure"),
    Input("filtro1", "value")
)
def actualizar_fig1(valor):
    fig, _ = crear_figura_1(df, valor)
    return fig

@app.callback(
    Output("fig2", "figure"),
    Input("filtro2", "value")
)
def actualizar_fig2(valor):
    fig, _ = crear_figura_2(coef_table, valor)
    return fig

@app.callback(
    Output("fig3", "figure"),
    Input("filtro3", "value")
)
def actualizar_fig3(valor):
    fig, _ = crear_figura_3(df, valor)
    return fig

@app.callback(
    Output("fig4", "figure"),
    Input("filtro4", "value")
)
def actualizar_fig4(valor):
    fig, _ = crear_figura_4(df, valor)
    return fig

# =============================================================
#  EJECUCIÓN (NO MODIFICAR)
# =============================================================
app.run(jupyter_mode="inline", port=8062)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8062/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
